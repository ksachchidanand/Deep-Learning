# %%
conda install pytorch torchvision torchaudio cpuonly -c pytorch
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/rename_z/miniconda3
#
#   added / updated specs:
#     - cpuonly
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     cpuonly-1.0                |                0           2 KB  pytorch
#     freetype-2.10.4            |       h5ab3b9f_0         596 KB
#     intel-openmp-2020.2        |              254         786 KB
#     jpeg-9b                    |       h024ee3a_2         214 KB
#     lcms2-2.11                 |       h396b838_0         307 KB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libtiff-4.1.0              |       h2733197_1         449 KB
#     libuv-1.40.0               |       h7b6447c_0         736 KB
#     lz4-c-1.9.2                |       heb0550a_3         175 KB
#     mkl-2020.2                 |              256       138.3 MB
#     mkl-service-2.3.0          |   py38he904b0f_0          62 KB
#     mkl_fft-1.2.0              |   py38h23d657b_0         157 KB
#     mkl_random-1.1.1           |   py38h0573a6f_0         341 KB
#     ninja-1.10.1               |   py38hfd86e86_0         1.4 MB
#     numpy-1.19.2               |   py38h54aff64_0          22 KB
#     numpy-base-1.19.2          |   py38hfa32c7d_0         4.2 MB
#     olefile-0.46               |             py_0          33 KB
#     pillow-8.0.1               |   py38he98fc37_0         620 KB
#     pytorch-1.7.0              |      py3.8_cpu_0        59.5 MB  pytorch
#     torchaudio-0.7.0           |             py38         9.9 MB  pytorch
#     torchvision-0.8.1          |         py38_cpu        17.2 MB  pytorch
#     typing_extensions-3.7.4.3  |             py_0          28 KB
#     zstd-1.4.5                 |       h9ceee32_0         619 KB
#     ------------------------------------------------------------
#                                            Total:       235.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   cpuonly            pytorch/noarch::cpuonly-1.0-0
#   freetype           pkgs/main/linux-64::freetype-2.10.4-h5ab3b9f_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2020.2-254
#   jpeg               pkgs/main/linux-64::jpeg-9b-h024ee3a_2
#   lcms2              pkgs/main/linux-64::lcms2-2.11-h396b838_0
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libtiff            pkgs/main/linux-64::libtiff-4.1.0-h2733197_1
#   libuv              pkgs/main/linux-64::libuv-1.40.0-h7b6447c_0
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.2-heb0550a_3
#   mkl                pkgs/main/linux-64::mkl-2020.2-256
#   mkl-service        pkgs/main/linux-64::mkl-service-2.3.0-py38he904b0f_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.2.0-py38h23d657b_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.1.1-py38h0573a6f_0
#   ninja              pkgs/main/linux-64::ninja-1.10.1-py38hfd86e86_0
#   numpy              pkgs/main/linux-64::numpy-1.19.2-py38h54aff64_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.19.2-py38hfa32c7d_0
#   olefile            pkgs/main/noarch::olefile-0.46-py_0
#   pillow             pkgs/main/linux-64::pillow-8.0.1-py38he98fc37_0
#   pytorch            pytorch/linux-64::pytorch-1.7.0-py3.8_cpu_0
#   torchaudio         pytorch/linux-64::torchaudio-0.7.0-py38
#   torchvision        pytorch/linux-64::torchvision-0.8.1-py38_cpu
#   typing_extensions  pkgs/main/noarch::typing_extensions-3.7.4.3-py_0
#   zstd               pkgs/main/linux-64::zstd-1.4.5-h9ceee32_0
#
#
#
# Downloading and Extracting Packages
# libuv-1.40.0         | 736 KB    | ##################################### | 100%
# pillow-8.0.1         | 620 KB    | ##################################### | 100%
# torchvision-0.8.1    | 17.2 MB   | ##################################### | 100%
# mkl-service-2.3.0    | 62 KB     | ##################################### | 100%
# libpng-1.6.37        | 278 KB    | ##################################### | 100%
# mkl-2020.2           | 138.3 MB  | ##################################### | 100%
# lcms2-2.11           | 307 KB    | ##################################### | 100%
# intel-openmp-2020.2  | 786 KB    | ##################################### | 100%
# jpeg-9b              | 214 KB    | ##################################### | 100%
# pytorch-1.7.0        | 59.5 MB   | ##################################### | 100%
# freetype-2.10.4      | 596 KB    | ##################################### | 100%
# olefile-0.46         | 33 KB     | ##################################### | 100%
# ninja-1.10.1         | 1.4 MB    | ##################################### | 100%
# mkl_random-1.1.1     | 341 KB    | ##################################### | 100%
# mkl_fft-1.2.0        | 157 KB    | ##################################### | 100%
# numpy-1.19.2         | 22 KB     | ##################################### | 100%
# typing_extensions-3. | 28 KB     | ##################################### | 100%
# zstd-1.4.5           | 619 KB    | ##################################### | 100%
# torchaudio-0.7.0     | 9.9 MB    | ##################################### | 100%
# libtiff-4.1.0        | 449 KB    | ##################################### | 100%
# numpy-base-1.19.2    | 4.2 MB    | ##################################### | 100%
# cpuonly-1.0          | 2 KB      | ##################################### | 100%
# lz4-c-1.9.2          | 175 KB    | ##################################### | 100%
# blas-1.0             | 6 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda list
# Out:
# # packages in environment at /home/rename_z/miniconda3:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# backcall                  0.2.0                      py_0
# blas                      1.0                         mkl
# ca-certificates           2020.10.14                    0
# certifi                   2020.6.20          pyhd3eb1b0_3
# cffi                      1.14.0           py38he30daa8_1
# chardet                   3.0.4                 py38_1003
# conda                     4.9.1            py38h06a4308_0
# conda-package-handling    1.6.1            py38h7b6447c_0
# cpuonly                   1.0                           0    pytorch
# cryptography              2.9.2            py38h1ba5d50_0
# decorator                 4.4.2                      py_0
# freetype                  2.10.4               h5ab3b9f_0
# idna                      2.9                        py_1
# intel-openmp              2020.2                      254
# ipykernel                 5.3.4            py38h5ca1d4c_0
# ipython                   7.19.0           py38hb070fc8_0
# ipython_genutils          0.2.0                    py38_0
# jedi                      0.17.2                   py38_0
# jpeg                      9b                   h024ee3a_2
# jupyter_client            6.1.7                      py_0
# jupyter_core              4.6.3                    py38_0
# lcms2                     2.11                 h396b838_0
# ld_impl_linux-64          2.33.1               h53a641e_7
# libedit                   3.1.20181209         hc058e9b_0
# libffi                    3.3                  he6710b0_1
# libgcc-ng                 9.1.0                hdf63c60_0
# libpng                    1.6.37               hbc83047_0
# libsodium                 1.0.18               h7b6447c_0
# libstdcxx-ng              9.1.0                hdf63c60_0
# libtiff                   4.1.0                h2733197_1
# libuv                     1.40.0               h7b6447c_0
# lz4-c                     1.9.2                heb0550a_3
# mkl                       2020.2                      256
# mkl-service               2.3.0            py38he904b0f_0
# mkl_fft                   1.2.0            py38h23d657b_0
# mkl_random                1.1.1            py38h0573a6f_0
# ncurses                   6.2                  he6710b0_1
# ninja                     1.10.1           py38hfd86e86_0
# numpy                     1.19.2           py38h54aff64_0
# numpy-base                1.19.2           py38hfa32c7d_0
# olefile                   0.46                       py_0
# openssl                   1.1.1h               h7b6447c_0
# parso                     0.7.0                      py_0
# pexpect                   4.8.0                    py38_0
# pickleshare               0.7.5                 py38_1000
# pillow                    8.0.1            py38he98fc37_0
# pip                       20.0.2                   py38_3
# prompt-toolkit            3.0.8                      py_0
# ptyprocess                0.6.0                    py38_0
# pycosat                   0.6.3            py38h7b6447c_1
# pycparser                 2.20                       py_0
# pygments                  2.7.2              pyhd3eb1b0_0
# pyopenssl                 19.1.0                   py38_0
# pysocks                   1.7.1                    py38_0
# python                    3.8.3                hcff3b4d_0
# python-dateutil           2.8.1                      py_0
# pytorch                   1.7.0               py3.8_cpu_0  [cpuonly]  pytorch
# pyzmq                     19.0.2           py38he6710b0_1
# readline                  8.0                  h7b6447c_0
# requests                  2.23.0                   py38_0
# ruamel_yaml               0.15.87          py38h7b6447c_0
# setuptools                46.4.0                   py38_0
# six                       1.14.0                   py38_0
# sqlite                    3.31.1               h62c20be_1
# tk                        8.6.8                hbc83047_0
# torchaudio                0.7.0                      py38    pytorch
# torchvision               0.8.1                  py38_cpu  [cpuonly]  pytorch
# tornado                   6.0.4            py38h7b6447c_1
# tqdm                      4.46.0                     py_0
# traitlets                 5.0.5                      py_0
# typing_extensions         3.7.4.3                    py_0
# urllib3                   1.25.8                   py38_0
# wcwidth                   0.2.5                      py_0
# wheel                     0.34.2                   py38_0
# xz                        5.2.5                h7b6447c_0
# yaml                      0.1.7                had09818_2
# zeromq                    4.3.3                he6710b0_3
# zlib                      1.2.11               h7b6447c_3
# zstd                      1.4.5                h9ceee32_0
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda clean -a -y
# Out:
# Cache location:
# There are no tarballs to remove
# WARNING: /home/rename_z/.conda/pkgs does not exist
# Cache location:
# There are no unused packages to remove
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda pandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/rename_z/miniconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.10.14 |                0         128 KB  anaconda
#     certifi-2020.6.20          |           py38_0         160 KB  anaconda
#     openssl-1.1.1h             |       h7b6447c_0         3.8 MB  anaconda
#     pandas-1.1.3               |   py38he6710b0_0        10.9 MB  anaconda
#     pytz-2020.1                |             py_0         239 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:        15.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             anaconda/linux-64::pandas-1.1.3-py38he6710b0_0
#   pytz               anaconda/noarch::pytz-2020.1-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates                                 pkgs/main --> anaconda
#   certifi            pkgs/main/noarch::certifi-2020.6.20-p~ --> anaconda/linux-64::certifi-2020.6.20-py38_0
#   openssl                                         pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1h       | 3.8 MB    | ##################################### | 100%
# certifi-2020.6.20    | 160 KB    | ##################################### | 100%
# pandas-1.1.3         | 10.9 MB   | ##################################### | 100%
# ca-certificates-2020 | 128 KB    | ##################################### | 100%
# pytz-2020.1          | 239 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda numpy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c pytorch torchtext
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# Warning: 4 possible package resolutions (only showing differing packages):
#   - anaconda/linux-64::ca-certificates-2020.10.14-0, anaconda/linux-64::openssl-1.1.1h-h7b6447c_0
#   - anaconda/linux-64::openssl-1.1.1h-h7b6447c_0, defaults/linux-64::ca-certificates-2020.10.14-0
#   - anaconda/linux-64::ca-certificates-2020.10.14-0, defaults/linux-64::openssl-1.1.1h-h7b6447c_0
#   - defaults/linux-64::ca-certificates-2020.10.14-0, defaults/linux-64::openssl-1.1.1h-h7b6447cdone
#
# ## Package Plan ##
#
#   environment location: /home/rename_z/miniconda3
#
#   added / updated specs:
#     - torchtext
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     torchtext-0.8.0            |             py38         8.0 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:         8.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   torchtext          pytorch/linux-64::torchtext-0.8.0-py38
#
# The following packages will be UPDATED:
#
#   certifi            anaconda/linux-64::certifi-2020.6.20-~ --> pkgs/main/noarch::certifi-2020.6.20-pyhd3eb1b0_3
#
#
#
# Downloading and Extracting Packages
# torchtext-0.8.0      | 8.0 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda spacy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/rename_z/miniconda3
#
#   added / updated specs:
#     - spacy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     attrs-20.2.0               |             py_0          41 KB  anaconda
#     catalogue-1.0.0            |           py38_1          15 KB  anaconda
#     cymem-2.0.3                |   py38he6710b0_0          43 KB  anaconda
#     cython-blis-0.4.1          |   py38h7b6447c_1         4.3 MB  anaconda
#     importlib-metadata-2.0.0   |             py_1          35 KB  anaconda
#     importlib_metadata-2.0.0   |                1          11 KB  anaconda
#     jsonschema-3.0.2           |           py38_0          92 KB  anaconda
#     murmurhash-1.0.2           |   py38he6710b0_0          27 KB  anaconda
#     plac-0.9.6                 |           py38_1          38 KB  anaconda
#     preshed-3.0.2              |   py38he6710b0_1         139 KB  anaconda
#     pyrsistent-0.17.3          |   py38h7b6447c_0          90 KB  anaconda
#     spacy-2.3.2                |   py38hfd86e86_0         8.4 MB  anaconda
#     srsly-1.0.2                |   py38he6710b0_0         220 KB  anaconda
#     thinc-7.4.1                |   py38hfd86e86_0         1.6 MB  anaconda
#     wasabi-0.8.0               |             py_0          22 KB  anaconda
#     zipp-3.3.1                 |             py_0          11 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:        15.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   attrs              anaconda/noarch::attrs-20.2.0-py_0
#   catalogue          anaconda/linux-64::catalogue-1.0.0-py38_1
#   cymem              anaconda/linux-64::cymem-2.0.3-py38he6710b0_0
#   cython-blis        anaconda/linux-64::cython-blis-0.4.1-py38h7b6447c_1
#   importlib-metadata anaconda/noarch::importlib-metadata-2.0.0-py_1
#   importlib_metadata anaconda/noarch::importlib_metadata-2.0.0-1
#   jsonschema         anaconda/linux-64::jsonschema-3.0.2-py38_0
#   murmurhash         anaconda/linux-64::murmurhash-1.0.2-py38he6710b0_0
#   plac               anaconda/linux-64::plac-0.9.6-py38_1
#   preshed            anaconda/linux-64::preshed-3.0.2-py38he6710b0_1
#   pyrsistent         anaconda/linux-64::pyrsistent-0.17.3-py38h7b6447c_0
#   spacy              anaconda/linux-64::spacy-2.3.2-py38hfd86e86_0
#   srsly              anaconda/linux-64::srsly-1.0.2-py38he6710b0_0
#   thinc              anaconda/linux-64::thinc-7.4.1-py38hfd86e86_0
#   wasabi             anaconda/noarch::wasabi-0.8.0-py_0
#   zipp               anaconda/noarch::zipp-3.3.1-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/noarch::certifi-2020.6.20-p~ --> anaconda/linux-64::certifi-2020.6.20-py38_0
#
#
#
# Downloading and Extracting Packages
# preshed-3.0.2        | 139 KB    | ##################################### | 100%
# importlib-metadata-2 | 35 KB     | ##################################### | 100%
# pyrsistent-0.17.3    | 90 KB     | ##################################### | 100%
# srsly-1.0.2          | 220 KB    | ##################################### | 100%
# spacy-2.3.2          | 8.4 MB    | ##################################### | 100%
# catalogue-1.0.0      | 15 KB     | ##################################### | 100%
# murmurhash-1.0.2     | 27 KB     | ##################################### | 100%
# attrs-20.2.0         | 41 KB     | ##################################### | 100%
# plac-0.9.6           | 38 KB     | ##################################### | 100%
# thinc-7.4.1          | 1.6 MB    | ##################################### | 100%
# cymem-2.0.3          | 43 KB     | ##################################### | 100%
# cython-blis-0.4.1    | 4.3 MB    | ##################################### | 100%
# importlib_metadata-2 | 11 KB     | ##################################### | 100%
# zipp-3.3.1           | 11 KB     | ##################################### | 100%
# jsonschema-3.0.2     | 92 KB     | ##################################### | 100%
# wasabi-0.8.0         | 22 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
